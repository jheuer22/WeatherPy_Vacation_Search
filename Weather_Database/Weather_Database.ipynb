# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a new set of 2,000 random latitudes and longitudes.
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Get the nearest city using the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descrip = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 15 | thinadhoo
# Processing Record 2 of Set 15 | hithadhoo
# Processing Record 3 of Set 15 | uniao da victoria
# City not found. Skipping...
# Processing Record 4 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 5 of Set 15 | caravelas
# Processing Record 6 of Set 15 | zhashkiv
# Processing Record 7 of Set 15 | ushuaia
# Processing Record 8 of Set 15 | sari
# Processing Record 9 of Set 15 | souillac
# Processing Record 10 of Set 15 | shingu
# Processing Record 11 of Set 15 | butaritari
# Processing Record 12 of Set 15 | kodiak
# Processing Record 13 of Set 15 | birao
# Processing Record 14 of Set 15 | zyryanka
# Processing Record 15 of Set 15 | tuktoyaktuk
# Processing Record 16 of Set 15 | buchanan
# Processing Record 17 of Set 15 | uige
# Processing Record 18 of Set 15 | jamestown
# Processing Record 19 of Set 15 | airai
# Processing Record 20 of Set 15 | codrington
# Processing Record 21 of Set 15 | hofn
# Processing Record 22 of Set 15 | vestmannaeyjar
# Processing Record 23 of Set 15 | hermanus
# Processing Record 24 of Set 15 | rikitea
# Processing Record 25 of Set 15 | hobart
# Processing Record 26 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 15 | cape town
# Processing Record 28 of Set 15 | mataura
# Processing Record 29 of Set 15 | san onofre
# Processing Record 30 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 15 | mar del plata
# Processing Record 32 of Set 15 | bethel
# Processing Record 33 of Set 15 | shaunavon
# Processing Record 34 of Set 15 | cam ranh
# Processing Record 35 of Set 15 | vaini
# Processing Record 36 of Set 15 | chuy
# Processing Record 37 of Set 15 | luderitz
# Processing Record 38 of Set 15 | santa maria da vitoria
# Processing Record 39 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 15 | albany
# Processing Record 41 of Set 15 | punta arenas
# Processing Record 42 of Set 15 | mahebourg
# Processing Record 43 of Set 15 | cidreira
# Processing Record 44 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 45 of Set 15 | portland
# Processing Record 46 of Set 15 | torbay
# Processing Record 47 of Set 15 | yertsevo
# Processing Record 48 of Set 15 | yaounde
# Processing Record 49 of Set 15 | taoudenni
# Processing Record 50 of Set 15 | kitimat
# Processing Record 1 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 16 | koping
# Processing Record 3 of Set 16 | yellowknife
# Processing Record 4 of Set 16 | mangrol
# Processing Record 5 of Set 16 | san patricio
# Processing Record 6 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 16 | kapaa
# Processing Record 8 of Set 16 | meulaboh
# Processing Record 9 of Set 16 | achisay
# City not found. Skipping...
# Processing Record 10 of Set 16 | tvoroyri
# Processing Record 11 of Set 16 | victoria
# Processing Record 12 of Set 16 | bluff
# Processing Record 13 of Set 16 | teguldet
# Processing Record 14 of Set 16 | broome
# Processing Record 15 of Set 16 | los llanos de aridane
# Processing Record 16 of Set 16 | omboue
# Processing Record 17 of Set 16 | pangnirtung
# Processing Record 18 of Set 16 | ous
# Processing Record 19 of Set 16 | vilyuysk
# Processing Record 20 of Set 16 | busselton
# Processing Record 21 of Set 16 | ancud
# Processing Record 22 of Set 16 | pevek
# Processing Record 23 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 16 | mount gambier
# Processing Record 25 of Set 16 | tasiilaq
# Processing Record 26 of Set 16 | provideniya
# Processing Record 27 of Set 16 | hede
# Processing Record 28 of Set 16 | leh
# Processing Record 29 of Set 16 | carnarvon
# Processing Record 30 of Set 16 | new norfolk
# Processing Record 31 of Set 16 | iqaluit
# Processing Record 32 of Set 16 | athabasca
# Processing Record 33 of Set 16 | awjilah
# Processing Record 34 of Set 16 | laguna
# Processing Record 35 of Set 16 | makakilo city
# Processing Record 36 of Set 16 | lagoa
# Processing Record 37 of Set 16 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 16 | saint george
# Processing Record 39 of Set 16 | buala
# Processing Record 40 of Set 16 | fortuna
# Processing Record 41 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 16 | katima mulilo
# Processing Record 43 of Set 16 | saint pete beach
# Processing Record 44 of Set 16 | labuhan
# Processing Record 45 of Set 16 | moose factory
# Processing Record 46 of Set 16 | esperance
# Processing Record 47 of Set 16 | cabo san lucas
# Processing Record 48 of Set 16 | katsuura
# Processing Record 49 of Set 16 | chapais
# Processing Record 50 of Set 16 | kavieng
# Processing Record 1 of Set 17 | varhaug
# Processing Record 2 of Set 17 | ulagan
# Processing Record 3 of Set 17 | alice springs
# Processing Record 4 of Set 17 | lebu
# Processing Record 5 of Set 17 | constitucion
# Processing Record 6 of Set 17 | touros
# Processing Record 7 of Set 17 | sisimiut
# Processing Record 8 of Set 17 | sitka
# Processing Record 9 of Set 17 | chambishi
# Processing Record 10 of Set 17 | vrangel
# Processing Record 11 of Set 17 | kargapolye
# City not found. Skipping...
# Processing Record 12 of Set 17 | nome
# Processing Record 13 of Set 17 | puerto ayora
# Processing Record 14 of Set 17 | charqueadas
# Processing Record 15 of Set 17 | udachnyy
# Processing Record 16 of Set 17 | ribeira grande
# Processing Record 17 of Set 17 | saskylakh
# Processing Record 18 of Set 17 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 17 | pierre
# Processing Record 20 of Set 17 | upernavik
# Processing Record 21 of Set 17 | itigi
# Processing Record 22 of Set 17 | saint-philippe
# Processing Record 23 of Set 17 | yerofey pavlovich
# Processing Record 24 of Set 17 | darhan
# Processing Record 25 of Set 17 | port alfred
# Processing Record 26 of Set 17 | caidian
# Processing Record 27 of Set 17 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 17 | clarence town
# Processing Record 29 of Set 17 | liwale
# Processing Record 30 of Set 17 | port elizabeth
# Processing Record 31 of Set 17 | narsaq
# Processing Record 32 of Set 17 | tiksi
# Processing Record 33 of Set 17 | vitoria
# Processing Record 34 of Set 17 | khatanga
# Processing Record 35 of Set 17 | taree
# Processing Record 36 of Set 17 | ponta delgada
# Processing Record 37 of Set 17 | balassagyarmat
# Processing Record 38 of Set 17 | vostok
# Processing Record 39 of Set 17 | lompoc
# Processing Record 40 of Set 17 | omsukchan
# Processing Record 41 of Set 17 | lorengau
# Processing Record 42 of Set 17 | east london
# Processing Record 43 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 17 | ponta do sol
# Processing Record 45 of Set 17 | saldanha
# Processing Record 46 of Set 17 | deputatskiy
# Processing Record 47 of Set 17 | castro
# Processing Record 48 of Set 17 | atuona
# Processing Record 49 of Set 17 | bredasdorp
# Processing Record 50 of Set 17 | bengkulu
# Processing Record 1 of Set 18 | abu dhabi
# Processing Record 2 of Set 18 | kaitangata
# Processing Record 3 of Set 18 | dikson
# Processing Record 4 of Set 18 | pangody
# Processing Record 5 of Set 18 | svetlogorsk
# Processing Record 6 of Set 18 | payo
# Processing Record 7 of Set 18 | melito di porto salvo
# Processing Record 8 of Set 18 | eidfjord
# Processing Record 9 of Set 18 | talnakh
# Processing Record 10 of Set 18 | hasaki
# Processing Record 11 of Set 18 | port-gentil
# Processing Record 12 of Set 18 | biltine
# Processing Record 13 of Set 18 | bonavista
# Processing Record 14 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 18 | palmer
# Processing Record 16 of Set 18 | barrow
# Processing Record 17 of Set 18 | vao
# Processing Record 18 of Set 18 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 18 | leningradskiy
# Processing Record 20 of Set 18 | honiara
# Processing Record 21 of Set 18 | port blair
# Processing Record 22 of Set 18 | clyde river
# Processing Record 23 of Set 18 | karratha
# Processing Record 24 of Set 18 | mount isa
# Processing Record 25 of Set 18 | boa vista
# Processing Record 26 of Set 18 | cherskiy
# Processing Record 27 of Set 18 | salalah
# Processing Record 28 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 18 | loukhi
# Processing Record 30 of Set 18 | sobolevo
# Processing Record 31 of Set 18 | christchurch
# Processing Record 32 of Set 18 | aracati
# Processing Record 33 of Set 18 | kiama
# Processing Record 34 of Set 18 | gvardeyskoye
# Processing Record 35 of Set 18 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 18 | rocha
# Processing Record 37 of Set 18 | malakal
# Processing Record 38 of Set 18 | nikolskoye
# Processing Record 39 of Set 18 | saint-joseph
# Processing Record 40 of Set 18 | dirba
# Processing Record 41 of Set 18 | bandarbeyla
# Processing Record 42 of Set 18 | ouadda
# Processing Record 43 of Set 18 | namatanai
# Processing Record 44 of Set 18 | araouane
# Processing Record 45 of Set 18 | burica
# City not found. Skipping...
# Processing Record 46 of Set 18 | sainte-maxime
# Processing Record 47 of Set 18 | oksfjord
# Processing Record 48 of Set 18 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 49 of Set 18 | labytnangi
# Processing Record 50 of Set 18 | minna
# Processing Record 1 of Set 19 | yar-sale
# Processing Record 2 of Set 19 | bambous virieux
# Processing Record 3 of Set 19 | tawkar
# City not found. Skipping...
# Processing Record 4 of Set 19 | alofi
# Processing Record 5 of Set 19 | pingliang
# Processing Record 6 of Set 19 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 19 | bara
# Processing Record 8 of Set 19 | dunedin
# Processing Record 9 of Set 19 | egvekinot
# Processing Record 10 of Set 19 | selenginsk
# Processing Record 11 of Set 19 | nytva
# Processing Record 12 of Set 19 | olafsvik
# Processing Record 13 of Set 19 | chifeng
# Processing Record 14 of Set 19 | luzhou
# Processing Record 15 of Set 19 | barabash
# Processing Record 16 of Set 19 | san policarpo
# Processing Record 17 of Set 19 | nantucket
# Processing Record 18 of Set 19 | okitipupa
# Processing Record 19 of Set 19 | harper
# Processing Record 20 of Set 19 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 19 | asau
# Processing Record 22 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 19 | dhidhdhoo
# Processing Record 24 of Set 19 | avarua
# Processing Record 25 of Set 19 | kango
# Processing Record 26 of Set 19 | river falls
# Processing Record 27 of Set 19 | maracas
# Processing Record 28 of Set 19 | malindi
# Processing Record 29 of Set 19 | qena
# Processing Record 30 of Set 19 | qaqortoq
# Processing Record 31 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 19 | george town
# Processing Record 33 of Set 19 | ballater
# Processing Record 34 of Set 19 | georgetown
# Processing Record 35 of Set 19 | ostrovnoy
# Processing Record 36 of Set 19 | rotenburg
# Processing Record 37 of Set 19 | ilulissat
# Processing Record 38 of Set 19 | sahrak
# City not found. Skipping...
# Processing Record 39 of Set 19 | elko
# Processing Record 40 of Set 19 | yalutorovsk
# Processing Record 41 of Set 19 | silyanah
# City not found. Skipping...
# Processing Record 42 of Set 19 | cloppenburg
# Processing Record 43 of Set 19 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 19 | catuday
# Processing Record 45 of Set 19 | seoul
# Processing Record 46 of Set 19 | santa isabel do rio negro
# Processing Record 47 of Set 19 | grants
# Processing Record 48 of Set 19 | bamnet narong
# Processing Record 49 of Set 19 | qaanaaq
# Processing Record 50 of Set 19 | hilo
# Processing Record 1 of Set 20 | campbeltown
# Processing Record 2 of Set 20 | mirabad
# Processing Record 3 of Set 20 | sovetskiy
# Processing Record 4 of Set 20 | paranapanema
# Processing Record 5 of Set 20 | lata
# Processing Record 6 of Set 20 | kahului
# Processing Record 7 of Set 20 | saint anthony
# Processing Record 8 of Set 20 | palmas de monte alto
# Processing Record 9 of Set 20 | bonthe
# Processing Record 10 of Set 20 | muros
# Processing Record 11 of Set 20 | gizo
# Processing Record 12 of Set 20 | norman wells
# Processing Record 13 of Set 20 | nioro
# Processing Record 14 of Set 20 | kotido
# Processing Record 15 of Set 20 | byron bay
# Processing Record 16 of Set 20 | port augusta
# Processing Record 17 of Set 20 | sur
# Processing Record 18 of Set 20 | bonfim
# Processing Record 19 of Set 20 | andarab
# City not found. Skipping...
# Processing Record 20 of Set 20 | vila
# Processing Record 21 of Set 20 | thompson
# Processing Record 22 of Set 20 | vaitape
# Processing Record 23 of Set 20 | talawdi
# City not found. Skipping...
# Processing Record 24 of Set 20 | dingle
# Processing Record 25 of Set 20 | vestbygda
# City not found. Skipping...
# Processing Record 26 of Set 20 | mahibadhoo
# Processing Record 27 of Set 20 | beringovskiy
# Processing Record 28 of Set 20 | deming
# Processing Record 29 of Set 20 | flinders
# Processing Record 30 of Set 20 | la asuncion
# Processing Record 31 of Set 20 | marawi
# Processing Record 32 of Set 20 | acapulco
# Processing Record 33 of Set 20 | pacific grove
# Processing Record 34 of Set 20 | whitianga
# Processing Record 35 of Set 20 | port hardy
# Processing Record 36 of Set 20 | safaga
# Processing Record 37 of Set 20 | sulphur springs
# Processing Record 38 of Set 20 | punta gorda
# Processing Record 39 of Set 20 | eskasem
# City not found. Skipping...
# Processing Record 40 of Set 20 | atherton
# Processing Record 41 of Set 20 | malanje
# Processing Record 42 of Set 20 | puerto ayacucho
# Processing Record 43 of Set 20 | knyaze-volkonskoye
# Processing Record 44 of Set 20 | waipawa
# Processing Record 45 of Set 20 | faanui
# Processing Record 46 of Set 20 | neryungri
# Processing Record 47 of Set 20 | bakel
# Processing Record 48 of Set 20 | ahuimanu
# Processing Record 49 of Set 20 | buenaventura
# Processing Record 50 of Set 20 | minas
# Processing Record 1 of Set 21 | fairbanks
# Processing Record 2 of Set 21 | ixtapa
# Processing Record 3 of Set 21 | estelle
# Processing Record 4 of Set 21 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 21 | evensk
# Processing Record 6 of Set 21 | tessalit
# Processing Record 7 of Set 21 | avera
# Processing Record 8 of Set 21 | pochutla
# Processing Record 9 of Set 21 | hobyo
# Processing Record 10 of Set 21 | samarai
# Processing Record 11 of Set 21 | galesong
# Processing Record 12 of Set 21 | chokurdakh
# Processing Record 13 of Set 21 | morehead
# Processing Record 14 of Set 21 | goundam
# Processing Record 15 of Set 21 | kachug
# Processing Record 16 of Set 21 | geraldton
# Processing Record 17 of Set 21 | glenwood springs
# Processing Record 18 of Set 21 | longyearbyen
# Processing Record 19 of Set 21 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 20 of Set 21 | medina
# Processing Record 21 of Set 21 | ilebo
# Processing Record 22 of Set 21 | mahanoro
# Processing Record 23 of Set 21 | cayenne
# Processing Record 24 of Set 21 | auki
# Processing Record 25 of Set 21 | andenes
# Processing Record 26 of Set 21 | kilrush
# Processing Record 27 of Set 21 | remiremont
# Processing Record 28 of Set 21 | irbeyskoye
# Processing Record 29 of Set 21 | belgrade
# Processing Record 30 of Set 21 | le vauclin
# Processing Record 31 of Set 21 | half moon bay
# Processing Record 32 of Set 21 | conde
# Processing Record 33 of Set 21 | shelburne
# Processing Record 34 of Set 21 | rudbar
# Processing Record 35 of Set 21 | haines junction
# Processing Record 36 of Set 21 | sao felix do xingu
# Processing Record 37 of Set 21 | kluczbork
# Processing Record 38 of Set 21 | krasnoselkup
# Processing Record 39 of Set 21 | hukuntsi
# Processing Record 40 of Set 21 | imeni babushkina
# Processing Record 41 of Set 21 | bang pakong
# Processing Record 42 of Set 21 | eureka
# Processing Record 43 of Set 21 | roma
# Processing Record 44 of Set 21 | nanortalik
# Processing Record 45 of Set 21 | kaura namoda
# Processing Record 46 of Set 21 | chitral
# Processing Record 47 of Set 21 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 21 | kulu
# Processing Record 49 of Set 21 | ternate
# Processing Record 50 of Set 21 | tayga
# Processing Record 1 of Set 22 | san angelo
# Processing Record 2 of Set 22 | sao jose da tapera
# Processing Record 3 of Set 22 | sistranda
# Processing Record 4 of Set 22 | tazovskiy
# Processing Record 5 of Set 22 | shintomi
# Processing Record 6 of Set 22 | albanel
# Processing Record 7 of Set 22 | romita
# Processing Record 8 of Set 22 | lavrentiya
# Processing Record 9 of Set 22 | bajo baudo
# City not found. Skipping...
# Processing Record 10 of Set 22 | naliya
# Processing Record 11 of Set 22 | padang
# Processing Record 12 of Set 22 | prachuap khiri khan
# Processing Record 13 of Set 22 | kumba
# Processing Record 14 of Set 22 | valjala
# City not found. Skipping...
# Processing Record 15 of Set 22 | nabire
# Processing Record 16 of Set 22 | mehamn
# Processing Record 17 of Set 22 | salinopolis
# Processing Record 18 of Set 22 | kralendijk
# Processing Record 19 of Set 22 | arraial do cabo
# Processing Record 20 of Set 22 | tautira
# Processing Record 21 of Set 22 | turochak
# Processing Record 22 of Set 22 | uusikaupunki
# Processing Record 23 of Set 22 | outjo
# Processing Record 24 of Set 22 | marsh harbour
# Processing Record 25 of Set 22 | preeceville
# Processing Record 26 of Set 22 | bairiki
# Processing Record 27 of Set 22 | santa ines
# Processing Record 28 of Set 22 | gidrotorf
# Processing Record 29 of Set 22 | santander
# Processing Record 30 of Set 22 | novoshakhtinsk
# Processing Record 31 of Set 22 | beaverlodge
# Processing Record 32 of Set 22 | tura
# Processing Record 33 of Set 22 | champerico
# Processing Record 34 of Set 22 | adrar
# Processing Record 35 of Set 22 | butembo
# Processing Record 36 of Set 22 | teguise
# Processing Record 37 of Set 22 | hvolsvollur
# Processing Record 38 of Set 22 | durazno
# Processing Record 39 of Set 22 | limenaria
# Processing Record 40 of Set 22 | pousat
# City not found. Skipping...
# Processing Record 41 of Set 22 | klaksvik
# Processing Record 42 of Set 22 | sabha
# Processing Record 43 of Set 22 | porto santo
# Processing Record 44 of Set 22 | vanavara
# Processing Record 45 of Set 22 | akyab
# Processing Record 46 of Set 22 | savalou
# Processing Record 47 of Set 22 | gallup
# Processing Record 48 of Set 22 | marystown
# Processing Record 49 of Set 22 | polson
# Processing Record 50 of Set 22 | vila velha
# Processing Record 1 of Set 23 | trat
# Processing Record 2 of Set 23 | jasper
# Processing Record 3 of Set 23 | saint-augustin
# Processing Record 4 of Set 23 | amarante do maranhao
# Processing Record 5 of Set 23 | mujiayingzi
# Processing Record 6 of Set 23 | guangzhou
# Processing Record 7 of Set 23 | pandan niog
# Processing Record 8 of Set 23 | berlevag
# Processing Record 9 of Set 23 | laurel
# Processing Record 10 of Set 23 | bamiantong
# Processing Record 11 of Set 23 | port keats
# Processing Record 12 of Set 23 | vardo
# Processing Record 13 of Set 23 | husavik
# Processing Record 14 of Set 23 | cascais
# Processing Record 15 of Set 23 | pangkalanbuun
# Processing Record 16 of Set 23 | karakendzha
# City not found. Skipping...
# Processing Record 17 of Set 23 | bermejo
# Processing Record 18 of Set 23 | pimentel
# Processing Record 19 of Set 23 | tshikapa
# Processing Record 20 of Set 23 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 23 | port lincoln
# Processing Record 22 of Set 23 | mastic beach
# Processing Record 23 of Set 23 | stephenville
# Processing Record 24 of Set 23 | guerrero negro
# Processing Record 25 of Set 23 | aktash
# Processing Record 26 of Set 23 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 23 | dinard
# Processing Record 28 of Set 23 | launceston
# Processing Record 29 of Set 23 | natitingou
# Processing Record 30 of Set 23 | kloulklubed
# Processing Record 31 of Set 23 | pisco
# Processing Record 32 of Set 23 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 23 | do gonbadan
# Processing Record 34 of Set 23 | linares
# Processing Record 35 of Set 23 | candido mendes
# Processing Record 36 of Set 23 | antofagasta
# Processing Record 37 of Set 23 | vylgort
# City not found. Skipping...
# Processing Record 38 of Set 23 | kosh-agach
# Processing Record 39 of Set 23 | moron
# Processing Record 40 of Set 23 | nargana
# Processing Record 41 of Set 23 | mumford
# Processing Record 42 of Set 23 | cairns
# Processing Record 43 of Set 23 | saint-gaudens
# Processing Record 44 of Set 23 | porto novo
# Processing Record 45 of Set 23 | richards bay
# Processing Record 46 of Set 23 | nenita
# Processing Record 47 of Set 23 | changji
# Processing Record 48 of Set 23 | mathathane
# Processing Record 49 of Set 23 | kirovskiy
# Processing Record 50 of Set 23 | wiwili
# Processing Record 1 of Set 24 | guilin
# Processing Record 2 of Set 24 | worland
# Processing Record 3 of Set 24 | michalovce
# Processing Record 4 of Set 24 | skagastrond
# City not found. Skipping...
# Processing Record 5 of Set 24 | kamenka
# Processing Record 6 of Set 24 | bouza
# Processing Record 7 of Set 24 | srednekolymsk
# Processing Record 8 of Set 24 | angoche
# Processing Record 9 of Set 24 | tadepallegudem
# Processing Record 10 of Set 24 | kottagudem
# Processing Record 11 of Set 24 | gat
# Processing Record 12 of Set 24 | karamken
# City not found. Skipping...
# Processing Record 13 of Set 24 | vila franca do campo
# Processing Record 14 of Set 24 | dzilam gonzalez
# Processing Record 15 of Set 24 | northam
# Processing Record 16 of Set 24 | ayna
# Processing Record 17 of Set 24 | samarkand
# Processing Record 18 of Set 24 | ossora
# Processing Record 19 of Set 24 | kyshtovka
# Processing Record 20 of Set 24 | lahij
# Processing Record 21 of Set 24 | montrose
# Processing Record 22 of Set 24 | griffith
# Processing Record 23 of Set 24 | newport
# Processing Record 24 of Set 24 | afrikanda
# Processing Record 25 of Set 24 | gohad
# Processing Record 26 of Set 24 | russell
# Processing Record 27 of Set 24 | westport
# Processing Record 28 of Set 24 | tlacotepec
# Processing Record 29 of Set 24 | corner brook
# Processing Record 30 of Set 24 | almeirim
# Processing Record 31 of Set 24 | kiunga
# Processing Record 32 of Set 24 | isangel
# Processing Record 33 of Set 24 | iracoubo
# Processing Record 34 of Set 24 | kifri
# Processing Record 35 of Set 24 | cap-aux-meules
# Processing Record 36 of Set 24 | suzhou
# Processing Record 37 of Set 24 | saint-pierre
# Processing Record 38 of Set 24 | quelimane
# Processing Record 39 of Set 24 | uvat
# Processing Record 40 of Set 24 | sao filipe
# Processing Record 41 of Set 24 | boyolangu
# Processing Record 42 of Set 24 | sao bento do una
# City not found. Skipping...
# Processing Record 43 of Set 24 | walvis bay
# Processing Record 44 of Set 24 | bathsheba
# Processing Record 45 of Set 24 | alim
# Processing Record 46 of Set 24 | nan
# Processing Record 47 of Set 24 | hudson bay
# Processing Record 48 of Set 24 | rosetta
# Processing Record 49 of Set 24 | sambava
# Processing Record 50 of Set 24 | maceio
# Processing Record 1 of Set 25 | sergach
# Processing Record 2 of Set 25 | lakes entrance
# Processing Record 3 of Set 25 | salamanca
# Processing Record 4 of Set 25 | ahipara
# Processing Record 5 of Set 25 | olinda
# Processing Record 6 of Set 25 | hualmay
# Processing Record 7 of Set 25 | ozernovskiy
# Processing Record 8 of Set 25 | olga
# Processing Record 9 of Set 25 | srandakan
# Processing Record 10 of Set 25 | camargo
# Processing Record 11 of Set 25 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 25 | zenzeli
# Processing Record 13 of Set 25 | kavaratti
# Processing Record 14 of Set 25 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 25 | sakakah
# Processing Record 16 of Set 25 | ostersund
# Processing Record 17 of Set 25 | teya
# Processing Record 18 of Set 25 | bhabua
# Processing Record 19 of Set 25 | pamanukan
# Processing Record 20 of Set 25 | hendrina
# Processing Record 21 of Set 25 | san quintin
# Processing Record 22 of Set 25 | kepno
# Processing Record 23 of Set 25 | baracoa
# Processing Record 24 of Set 25 | machali
# Processing Record 25 of Set 25 | tandil
# Processing Record 26 of Set 25 | sao joao da barra
# Processing Record 27 of Set 25 | plerin
# Processing Record 28 of Set 25 | moelv
# Processing Record 29 of Set 25 | fort nelson
# Processing Record 30 of Set 25 | solnechnyy
# Processing Record 31 of Set 25 | lokosovo
# Processing Record 32 of Set 25 | phan thiet
# Processing Record 33 of Set 25 | komsomolskiy
# Processing Record 34 of Set 25 | roblin
# Processing Record 35 of Set 25 | san-pedro
# Processing Record 36 of Set 25 | nichinan
# Processing Record 37 of Set 25 | matamoros
# Processing Record 38 of Set 25 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 25 | mehran
# Processing Record 40 of Set 25 | neiafu
# Processing Record 41 of Set 25 | kudahuvadhoo
# Processing Record 42 of Set 25 | doha
# Processing Record 43 of Set 25 | areka
# Processing Record 44 of Set 25 | sola
# Processing Record 45 of Set 25 | hay river
# Processing Record 46 of Set 25 | manokwari
# Processing Record 47 of Set 25 | taksimo
# Processing Record 48 of Set 25 | gravelbourg
# Processing Record 49 of Set 25 | payson
# Processing Record 50 of Set 25 | ucluelet
# Processing Record 1 of Set 26 | monki
# Processing Record 2 of Set 26 | orlovskiy
# Processing Record 3 of Set 26 | pavlohrad
# Processing Record 4 of Set 26 | nea peramos
# Processing Record 5 of Set 26 | smoky lake
# Processing Record 6 of Set 26 | vermillion
# Processing Record 7 of Set 26 | bielsk podlaski
# Processing Record 8 of Set 26 | dinar
# Processing Record 9 of Set 26 | ca mau
# Processing Record 10 of Set 26 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 26 | hovd
# Processing Record 12 of Set 26 | yuanping
# Processing Record 13 of Set 26 | eydhafushi
# Processing Record 14 of Set 26 | aksarka
# Processing Record 15 of Set 26 | maningrida
# Processing Record 16 of Set 26 | korla
# Processing Record 17 of Set 26 | eufaula
# Processing Record 18 of Set 26 | ilhabela
# Processing Record 19 of Set 26 | kaohsiung
# Processing Record 20 of Set 26 | morant bay
# Processing Record 21 of Set 26 | huarmey
# Processing Record 22 of Set 26 | begles
# Processing Record 23 of Set 26 | laukaa
# Processing Record 24 of Set 26 | kasulu
# Processing Record 25 of Set 26 | oranjemund
# Processing Record 26 of Set 26 | trinidad
# Processing Record 27 of Set 26 | presque isle
# Processing Record 28 of Set 26 | karpathos
# Processing Record 29 of Set 26 | belmonte
# Processing Record 30 of Set 26 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 26 | iquique
# Processing Record 32 of Set 26 | mogadishu
# Processing Record 33 of Set 26 | saint-marc
# Processing Record 34 of Set 26 | nouadhibou
# Processing Record 35 of Set 26 | nouakchott
# Processing Record 36 of Set 26 | gryazovets
# Processing Record 37 of Set 26 | winnemucca
# Processing Record 38 of Set 26 | margate
# Processing Record 39 of Set 26 | toftir
# City not found. Skipping...
# Processing Record 40 of Set 26 | kathu
# Processing Record 41 of Set 26 | hamilton
# Processing Record 42 of Set 26 | naze
# Processing Record 43 of Set 26 | naryan-mar
# Processing Record 44 of Set 26 | krasnooktyabrskiy
# Processing Record 45 of Set 26 | stykkisholmur
# Processing Record 46 of Set 26 | faya
# Processing Record 47 of Set 26 | huinan
# Processing Record 48 of Set 26 | stephenville crossing
# Processing Record 49 of Set 26 | mao
# Processing Record 50 of Set 26 | sibolga
# Processing Record 1 of Set 27 | marienburg
# Processing Record 2 of Set 27 | san carlos de bariloche
# Processing Record 3 of Set 27 | poum
# Processing Record 4 of Set 27 | saint-honore
# Processing Record 5 of Set 27 | chaupimarca
# Processing Record 6 of Set 27 | severo-kurilsk
# Processing Record 7 of Set 27 | ekuvukeni
# Processing Record 8 of Set 27 | xining
# Processing Record 9 of Set 27 | progreso
# Processing Record 10 of Set 27 | saint-leu
# Processing Record 11 of Set 27 | san jose
# Processing Record 12 of Set 27 | tabas
# Processing Record 13 of Set 27 | la romana
# Processing Record 14 of Set 27 | coquimbo
# Processing Record 15 of Set 27 | kununurra
# Processing Record 16 of Set 27 | riaba
# City not found. Skipping...
# Processing Record 17 of Set 27 | kuminskiy
# Processing Record 18 of Set 27 | saint-raymond
# Processing Record 19 of Set 27 | todi
# Processing Record 20 of Set 27 | nelson bay
# Processing Record 21 of Set 27 | novo aripuana
# Processing Record 22 of Set 27 | anqing
# Processing Record 23 of Set 27 | hami
# Processing Record 24 of Set 27 | kruisfontein
# Processing Record 25 of Set 27 | lunenburg
# Processing Record 26 of Set 27 | marzuq
# Processing Record 27 of Set 27 | cockburn town
# Processing Record 28 of Set 27 | xingcheng
# Processing Record 29 of Set 27 | killarney
# Processing Record 30 of Set 27 | guadalupe y calvo
# Processing Record 31 of Set 27 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 27 | maniitsoq
# Processing Record 33 of Set 27 | yarkovo
# Processing Record 34 of Set 27 | orzu
# Processing Record 35 of Set 27 | laem sing
# Processing Record 36 of Set 27 | waingapu
# Processing Record 37 of Set 27 | ambon
# Processing Record 38 of Set 27 | lahad datu
# Processing Record 39 of Set 27 | chauk
# Processing Record 40 of Set 27 | santa
# Processing Record 41 of Set 27 | kamina
# Processing Record 42 of Set 27 | snasa
# Processing Record 43 of Set 27 | galgani
# City not found. Skipping...
# Processing Record 44 of Set 27 | vangaindrano
# Processing Record 45 of Set 27 | alyangula
# Processing Record 46 of Set 27 | katherine
# Processing Record 47 of Set 27 | sarangani
# Processing Record 48 of Set 27 | cabra
# Processing Record 49 of Set 27 | chanika
# Processing Record 50 of Set 27 | bagdarin
# Processing Record 1 of Set 28 | yulara
# Processing Record 2 of Set 28 | west wendover
# Processing Record 3 of Set 28 | umm lajj
# Processing Record 4 of Set 28 | matagami
# Processing Record 5 of Set 28 | marau
# Processing Record 6 of Set 28 | pervomayskiy
# Processing Record 7 of Set 28 | flin flon
# Processing Record 8 of Set 28 | mezen
# Processing Record 9 of Set 28 | tomatlan
# Processing Record 10 of Set 28 | goderich
# Processing Record 11 of Set 28 | sesimbra
# Processing Record 12 of Set 28 | balakhta
# Processing Record 13 of Set 28 | los banos
# Processing Record 14 of Set 28 | havre-saint-pierre
# Processing Record 15 of Set 28 | obregon
# Processing Record 16 of Set 28 | nishihara
# Processing Record 17 of Set 28 | jutai
# Processing Record 18 of Set 28 | ndouci
# City not found. Skipping...
# Processing Record 19 of Set 28 | jiaxing
# Processing Record 20 of Set 28 | viseu
# Processing Record 21 of Set 28 | katha
# City not found. Skipping...
# Processing Record 22 of Set 28 | khani
# Processing Record 23 of Set 28 | kipini
# Processing Record 24 of Set 28 | urucara
# Processing Record 25 of Set 28 | sinnamary
# Processing Record 26 of Set 28 | eyl
# Processing Record 27 of Set 28 | zemio
# Processing Record 28 of Set 28 | asyut
# Processing Record 29 of Set 28 | resende
# Processing Record 30 of Set 28 | sapulpa
# Processing Record 31 of Set 28 | falealupo
# City not found. Skipping...
# Processing Record 32 of Set 28 | fort-shevchenko
# Processing Record 33 of Set 28 | voi
# Processing Record 34 of Set 28 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 28 | ust-nera
# Processing Record 36 of Set 28 | boffa
# Processing Record 37 of Set 28 | presidencia roque saenz pena
# Processing Record 38 of Set 28 | puerto escondido
# Processing Record 39 of Set 28 | bo phloi
# Processing Record 40 of Set 28 | luba
# Processing Record 41 of Set 28 | hammerfest
# Processing Record 42 of Set 28 | qasigiannguit
# Processing Record 43 of Set 28 | vuktyl
# Processing Record 44 of Set 28 | antalaha
# Processing Record 45 of Set 28 | dezhou
# Processing Record 46 of Set 28 | mwingi
# Processing Record 47 of Set 28 | mayo
# Processing Record 48 of Set 28 | cassilandia
# Processing Record 49 of Set 28 | sheffield
# Processing Record 50 of Set 28 | taltal
# Processing Record 1 of Set 29 | mana
# Processing Record 2 of Set 29 | ketchikan
# Processing Record 3 of Set 29 | iki-burul
# Processing Record 4 of Set 29 | xai-xai
# Processing Record 5 of Set 29 | spearfish
# Processing Record 6 of Set 29 | ust-koksa
# Processing Record 7 of Set 29 | buzuluk
# Processing Record 8 of Set 29 | lapua
# Processing Record 9 of Set 29 | san ignacio
# Processing Record 10 of Set 29 | dachau
# Processing Record 11 of Set 29 | hoquiam
# Processing Record 12 of Set 29 | subaytilah
# City not found. Skipping...
# Processing Record 13 of Set 29 | imeni morozova
# Processing Record 14 of Set 29 | ambositra
# Processing Record 15 of Set 29 | ust-tsilma
# Processing Record 16 of Set 29 | simao
# Processing Record 17 of Set 29 | le port
# Processing Record 18 of Set 29 | bilma
# Processing Record 19 of Set 29 | zhigansk
# Processing Record 20 of Set 29 | felipe carrillo puerto
# Processing Record 21 of Set 29 | pontianak
# Processing Record 22 of Set 29 | druzhba
# Processing Record 23 of Set 29 | dwarka
# Processing Record 24 of Set 29 | ewa beach
# Processing Record 25 of Set 29 | gazalkent
# Processing Record 26 of Set 29 | karauzyak
# City not found. Skipping...
# Processing Record 27 of Set 29 | sonneberg
# Processing Record 28 of Set 29 | playa vicente
# Processing Record 29 of Set 29 | kwinana
# Processing Record 30 of Set 29 | ranong
# Processing Record 31 of Set 29 | manaure
# Processing Record 32 of Set 29 | te anau
# Processing Record 33 of Set 29 | tete
# Processing Record 34 of Set 29 | kytmanovo
# Processing Record 35 of Set 29 | kidal
# Processing Record 36 of Set 29 | inhambane
# Processing Record 37 of Set 29 | breytovo
# Processing Record 38 of Set 29 | teknaf
# Processing Record 39 of Set 29 | krasnyy yar
# Processing Record 40 of Set 29 | florian
# Processing Record 41 of Set 29 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 42 of Set 29 | itoman
# Processing Record 43 of Set 29 | biak
# Processing Record 44 of Set 29 | coihaique
# Processing Record 45 of Set 29 | asfi
# Processing Record 46 of Set 29 | uchiza
# Processing Record 47 of Set 29 | melfi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Thinadhoo   0.5333   72.9333     82.56        69          39        9.51
# 1   Hithadhoo  -0.6000   73.0833     81.23        75         100        9.51
# 2   Caravelas -17.7125  -39.2481     73.81        86         100       10.83
# 3    Zhashkiv  49.2454   30.1102     57.06        53          59       13.47
# 4     Ushuaia -54.8000  -68.3000     38.86        87          75       27.63
# 5        Sari  36.5633   53.0601     52.39        81           3        4.21
# 6    Souillac -20.5167   57.5167     74.35        88          75        6.91
# 7      Shingu  33.7333  135.9833     59.99        83         100        3.65
# 8  Butaritari   3.0707  172.7902     82.96        72          27       13.96
# 9      Kodiak  57.7900 -152.4072     44.11        61          75       11.50
#
#   Country Weather Description
# 0      MV    scattered clouds
# 1      MV     overcast clouds
# 2      BR     overcast clouds
# 3      UA       broken clouds
# 4      AR       broken clouds
# 5      IR           clear sky
# 6      MU       broken clouds
# 7      JP          light rain
# 8      KI    scattered clouds
# 9      US       broken clouds

# %%
new_column_order= ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Weather Description']

# %%
city_data_df=city_data_df[new_column_order]

# %%
city_data_df.head()
# Out:
#         City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Thinadhoo      MV   0.5333  72.9333     82.56        69          39
# 1  Hithadhoo      MV  -0.6000  73.0833     81.23        75         100
# 2  Caravelas      BR -17.7125 -39.2481     73.81        86         100
# 3   Zhashkiv      UA  49.2454  30.1102     57.06        53          59
# 4    Ushuaia      AR -54.8000 -68.3000     38.86        87          75
#
#    Wind Speed Weather Description
# 0        9.51    scattered clouds
# 1        9.51     overcast clouds
# 2       10.83     overcast clouds
# 3       13.47       broken clouds
# 4       27.63       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
